# %%
# %pylab inline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=loadtxt('bmw.csv', delimiter=',')

# %%
y_train, x_train = data[:,0].astype(uint8), data[:,1:]

# %%
scatter(x_train[:,0], x_train[:,1], c=y_train)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle, class_weight

# %%
scaler=MinMaxScaler()

# %%
scaler.fit_transform(x_train, y_train)
# Out:
# array([[0.85343994, 0.31292727],
#        [0.89425692, 0.54313663],
#        [0.22653201, 0.40652896],
#        ...,
#        [0.4215304 , 0.58784253],
#        [0.76267678, 0.90578042],
#        [0.86949772, 0.45640496]])
