# %%
# %pylab inline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=linspace(0, 100*pi, 2000)

# %%
x=sin(t)+sin(3*t)/3+sin(5*t)/5
# x=sin(t)

# %%
plot(x, "k.-")

# %%
scaler=MinMaxScaler()

# %%
x=scaler.fit_transform(x.reshape(-1,1))

# %%
N=x.shape[0]

# %%
N
# Out:
# 2000

# %%
X=[]
Y=[]
P=1024 # liczba wektorów uczących
L=20 # szerokość okna (liczba próbek)
for i in range(P):
    pos=randint(N-L)
    X.append(x[pos:pos+L,0])
    Y.append([x[pos+L,0]])
X=array(X)
Y=array(Y)

# %%
X.shape, Y.shape
# Out:
# ((1024, 20), (1024, 1))

# %%
model = keras.models.Sequential()
model.add(layers.Dense(10, input_dim=L, activation='sigmoid'))
model.add(layers.Dense(20, activation='sigmoid'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss="mse", optimizer='adam')

# %%
model.fit(X, Y, epochs=50, verbose=0, batch_size=16);

# %%
model.evaluate(X,Y)
# Out:
# 1024/1024 [==============================] - 0s 256us/sample - loss: 8.3045e-04
# 0.0008304532348120119

# %%
pred=x[0:L,0].tolist() # bootstrap

# %%
for i in range(100):
    pred.append(model.predict(array(pred[-L:]).reshape(-1,L))[0,0])

# %%
plot(x[0:L,0], "k.")
plot(pred)

# %%
model.weights
# Out:
# [<tf.Variable 'dense_3/kernel:0' shape=(20, 10) dtype=float32, numpy=
#  array([[-0.09237979,  0.5130262 , -0.6662232 ,  0.51005906, -0.9551234 ,
#          -0.28507942, -0.47684315, -0.14813854,  0.6389762 ,  0.1069571 ],
#         [ 0.23658071,  0.26079088, -0.6380832 ,  0.0330077 , -0.35302982,
#          -0.67673993, -0.3443254 , -0.49874353,  0.28542948,  0.84041   ],
#         [ 0.919765  ,  0.03749396, -0.00963413,  0.43178517,  0.09173606,
#          -0.3578426 , -0.4675386 , -1.0244762 ,  0.64240706,  0.6794154 ],
#         [ 1.0125209 ,  0.31044042, -0.08325581,  0.5365207 ,  0.66220206,
#           0.360357  ,  0.38580468, -1.1844661 ,  0.3857826 , -0.15500781],
#         [ 0.8573195 , -0.52229595, -0.6325732 ,  0.2650718 , -0.01488855,
#           0.6622006 ,  0.5310353 , -1.328237  ,  0.40817675, -0.52570385],
#         [ 0.6510767 , -0.10469573, -0.29987627, -0.13571449,  0.5602431 ,
#           0.5694081 ,  0.11929033, -1.012167  ,  0.6315826 , -0.15247597],
#         [ 0.49438247, -0.07922059, -0.35529283, -0.01657767,  0.45062813,
#           0.31659254,  0.01375543, -0.5923197 ,  0.38503772, -0.45085615],
#         [-0.3891984 ,  0.26085016, -0.3585929 ,  0.07850432, -0.01588286,
#          -0.33828273, -0.31164142,  0.46955448,  0.04249541, -0.41670516],
#         [ 0.1789224 , -0.22260264,  0.29111502, -0.12840857, -0.4221952 ,
#          -0.09058644, -0.16888872,  0.05915228,  0.10309251,  0.4539785 ],
#         [-0.2652881 ,  0.23353553,  0.45047164, -0.10031474, -0.53917354,
#          -0.48715168,  0.27655247,  0.45700353,  0.08679128, -0.2001639 ],
#         [-0.37917045,  0.27231643, -0.07177055,  0.44824684, -0.20228235,
#          -0.24417266, -0.44472262,  0.5182088 , -0.52391297, -0.2722481 ],
#         [-0.18798485, -0.26112804, -0.02160839,  0.07021109, -0.35473934,
#          -0.04628597,  0.33273682, -0.10940583, -0.34606493, -0.18686242],
#         [ 0.2541062 , -0.58975506,  0.2643679 ,  0.33077928,  0.21053271,
#          -7.0396280e-01,  1.7446326e-01,  3.5015118e-01,  6.8030477e-01,
#           5.5567479e-01, -4.9570674e-01,  3.4884435e-01,  5.8785063e-01,
#           4.5848563e-01,  4.8682848e-01,  3.7665707e-03,  2.5674212e-01],
#         [-4.8903733e-01, -1.3311256e-01,  4.0789929e-01, -5.2993357e-01,
#           1.3448663e-01, -3.1348708e-01, -6.4227021e-01, -4.6234441e-01,
#          -6.7694515e-01,  6.1841106e-01,  2.7792913e-01,  1.7759113e-01,
#           8.8903755e-01, -2.5246093e-01,  2.2145768e-01,  1.4445841e-01,
#           9.4297868e-01,  4.4026890e-01, -4.3510711e-01,  4.5506823e-01],
#         [-6.9221616e-01, -7.4557889e-01,  6.9125193e-01, -4.8711592e-01,
#           5.7161433e-01, -6.9796902e-01, -6.2324226e-01, -3.7122661e-01,
#          -7.4452007e-01,  5.0498563e-01,  4.6637592e-01,  3.5060254e-01,
#           7.2334504e-01, -3.4576693e-01,  8.1553924e-01, -8.8084407e-02,
#           5.8295292e-01,  3.3059287e-01, -5.8044565e-01,  7.6758228e-02],
#         [-8.7094404e-02, -8.2386976e-01,  4.5206636e-01, -3.2691023e-01,
#           8.5679412e-01, -3.2657588e-01, -6.4622706e-01, -6.2537706e-01,
#          -4.3668133e-01,  7.9679507e-01,  4.6191645e-01,  1.5051925e-01,
#           4.3558720e-01, -3.5685375e-01,  3.9240617e-01,  6.7233878e-01,
#           6.1849475e-01,  5.3737980e-01, -1.0301549e+00,  4.1956571e-01],
#         [ 3.8185170e-01,  5.1229131e-01, -3.5699612e-01,  5.6313485e-01,
#          -2.6556605e-01,  5.6438673e-01,  1.4352944e-02,  5.3973073e-01,
#           6.1012948e-01, -2.6937053e-01, -4.8509791e-01, -3.5257575e-01,
#          -4.2884026e-02,  3.0780397e-02,  2.1734329e-02, -8.6086780e-01,
#          -4.4845048e-02, -7.7966237e-01, -7.3736884e-02, -1.9959849e-01],
#         [ 7.6806992e-01,  1.0553532e+00, -3.2875773e-01,  6.3918078e-01,
#          -6.7838937e-01,  2.7644882e-01,  8.9137697e-01,  5.5927551e-01,
#           7.9784471e-01, -1.0730141e+00, -4.6893865e-01, -3.1854025e-01,
#          -1.0379603e+00,  2.2730708e-01, -9.9799383e-01, -2.1160853e-01,
#          -9.0499252e-01, -6.5004033e-01,  1.0221004e+00, -6.9864011e-01]],
#        dtype=float32)>,
#  <tf.Variable 'dense_4/bias:0' shape=(20,) dtype=float32, numpy=
#  array([-0.01617474, -0.11762207,  0.05147227,  0.02865248, -0.0003596 ,
#          0.16861962, -0.01663407, -0.02186681,  0.03252149, -0.01577968,
#         -0.02097039, -0.09207155, -0.1520249 ,  0.12292349,  0.08522955,
#         -0.03788803, -0.05822744,  0.16914359, -0.03951139,  0.00579321],
#        dtype=float32)>,
#  <tf.Variable 'dense_5/kernel:0' shape=(20, 1) dtype=float32, numpy=
#  array([[-0.56250083],
#         [-0.51083654],
#         [ 0.5493163 ],
#         [-0.89885396],
#         [ 0.51244235],
#         [-0.92062974],
#         [-0.86701345],
#         [-0.7980694 ],
#         [-0.6237468 ],
#         [ 0.6006066 ],
#         [ 0.5271282 ],
#         [ 0.81384695],
#         [ 0.38929468],
#         [-0.62517226],
#         [ 0.59922254],
#         [ 0.5842618 ],
#         [ 0.83553404],
#         [ 0.48090807],
#         [-0.6843766 ],
#         [ 0.4579215 ]], dtype=float32)>,
#  <tf.Variable 'dense_5/bias:0' shape=(1,) dtype=float32, numpy=array([-0.01750909], dtype=float32)>]
